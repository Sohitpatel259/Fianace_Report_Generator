# %%
# !pip install groq yfinance agno
# !pip install groq duckduckgo-search newspaper4k lxml_html_clean agno
# !pip install -U sqlalchemy 'psycopg[binary]' pgvector pypdf agno
# !pip install udocker
# !pip install sentence-transformers
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#     --------------------------------------- 0.0/2.1 MB 991.0 kB/s eta 0:00:03
#    - -------------------------------------- 0.1/2.1 MB 1.1 MB/s eta 0:00:02
#    -- ------------------------------------- 0.1/2.1 MB 1.1 MB/s eta 0:00:02
#    --- ------------------------------------ 0.2/2.1 MB 952.6 kB/s eta 0:00:03
#    --- ------------------------------------ 0.2/2.1 MB 958.4 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.3/2.1 MB 1.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.3/2.1 MB 981.5 kB/s eta 0:00:02
#    ------ --------------------------------- 0.4/2.1 MB 995.6 kB/s eta 0:00:02
# ...

# %%
import os
GROQ_API_KEY=os.environ.get('GROQ_API_KEY')
AGNO_API_KEY = os.environ.get('AGNO_API_KEY')
print("API keys have been set!")
# Out:
# API keys have been set!

# %%
# Check if API keys are properly set
if GROQ_API_KEY is None or GROQ_API_KEY == "":
    print("⚠️ WARNING: GROQ_API_KEY is not set!")
    print("Please set your GROQ_API_KEY environment variable or add it directly:")
    print("GROQ_API_KEY = 'your-api-key-here'")
else:
    print(f"✓ GROQ_API_KEY is set (length: {len(GROQ_API_KEY)} characters)")

if AGNO_API_KEY is None or AGNO_API_KEY == "":
    print("⚠️ WARNING: AGNO_API_KEY is not set (this may be optional)")
else:
    print(f"✓ AGNO_API_KEY is set (length: {len(AGNO_API_KEY)} characters)")
# Out:
# ✓ GROQ_API_KEY is set (length: 56 characters)
# ✓ AGNO_API_KEY is set (length: 46 characters)

# %%
'''
from agno.models.groq import groq
model = Groq(id="llama3-70b-8192")
'''
# Out:
# '\nfrom agno.models.groq import groq\nmodel = Groq(id="llama3-70b-8192")\n'

# %%
# !pip install agno
import agno
print(f"agno version: {agno.__version__}")
# Out:
# ...
# agno version: 2.3.12
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install groq ddgs newspaper4k lxml_html_clean
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from textwrap import dedent
from agno.agent import Agent
from agno.models.groq import Groq
from agno.tools.duckduckgo import DuckDuckGoTools
from agno.tools.newspaper4k import Newspaper4kTools

# %%
research_agent = Agent(
    model = Groq(id="llama-3.3-70b-versatile"),
    tools = [
        DuckDuckGoTools(),
        Newspaper4kTools()],
    description=dedent("""
    You are an elite research analyst in the financial services domain.
    Your expertise encompasses:

    -Deep investigative financial research and analysis
    -fact-checking and source verification
    -Data-driven reporting and visualization
    -Expert interview synthesis
    -Trend analysis and future predictions
    -Complex topic simplification
    -Ethical practices
    -Balanced perspective presentation
    -Global context integration
    """

    ),
    instructions=dedent("""
    1. Research Phase
      -Search for 5 authoritative sources on the topic
      -Prioritize recent publications and expert opinions
      -Identify key stakeholders and perspectives

    2. Analysis Phase
      -Extract and verify critical information
      -Cross-reference across multiple sources
      -Identify emerging patterns and trends
      -Evaluate conflicting viewpoints
    3. Writing Phase
     -Craft an attention-grabbing headline
     -Structure content in Financial Report style
     -Include relevant quotes and statistics
     -Maintain objectivity and balance
     -Explain complex concepts clearly

  4. Quality Phase
    -Verify all facts and attributions
    -Ensure narrative flow and readability
    -Add context where necessary
    -Include future implications

"""
    ),
expected_output=dedent("""
     #{Compelling Headline}
     ## Executive Summary
     {Concise overview of key findings and significance}

     ## Background & Context
     {Historical context and importance}
     {Current landscape overview}

     ## Key Findings
     {Main discoveries and analysis}
     {Expert insights and quotes}

     ## Impact Analysis
     {Current implications}
     {Stakeholder perspectives}
     {Industry/societal effects}

     ## Future Outlook
     {Emerging trends}
     {Expert predictions}
     {Potential challenges and opportunities}

     ## Expert Insights
     {Notable quotes and analysis from industry leaders}
     {Contrasting viewpoints}

     ## Sources and Methodology
     {List of primary sources with key contributions}
     {Provide https:// links of all the primary sources}
     {Research methodology overview}


     ---
     Research conducted by Financial Agent
     Credit Rating Style Report
     Published:{current date}
     Last Updated:{current date}
  """),
  markdown=True,

)
# Run the research agent and get response
try:
    print("Starting research agent...")
    print("=" * 80)
    
    # Run without streaming to get the full response
    response = research_agent.run(
        "Analyze the current state and future implications of artificial Intelligence in Finance"
    )
    
    print("\n" + "=" * 80)
    print("RESEARCH REPORT:")
    print("=" * 80)
    print(response.content)
    print("\n" + "=" * 80)
    print("✓ Research completed!")
    
except Exception as e:
    print(f"❌ Error occurred: {type(e).__name__}")
    print(f"Error message: {str(e)}")
    import traceback
    traceback.print_exc()
# Run the agent and display the response
response = research_agent.run("Analyze the current state and future implications of artificial Intelligence in Finance")
print(response.content)
# Out:
# Starting research agent...
# ...
#
# ...
# RESEARCH REPORT:
# ...
# # Artificial Intelligence in Finance: A New Era of Efficiency and Risk
# ## Executive Summary
# The integration of artificial intelligence (AI) in finance has revolutionized the industry, bringing about unprecedented efficiency, accuracy, and speed. However, it also poses significant risks and challenges. This report provides an in-depth analysis of the current state and future implications of AI in finance, highlighting its benefits, drawbacks, and potential consequences.
#
# ## Background & Context
# The financial sector has undergone significant transformations in recent years, driven by technological advancements and changing consumer behavior. The introduction of AI has been a key driver of this change, enabling financial institutions to automate processes, improve customer service, and enhance decision-making.
#
# ## Key Findings
# ...

# %%
# User Prompt 2
research_agent.print_response("Applications of Gen AI in Financial Services",stream=True,)
print(response.content)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# # Artificial Intelligence in Finance: A New Era of Innovation and Risk
# ## Executive Summary
# The integration of artificial intelligence (AI) in finance is transforming the industry, bringing about unprecedented opportunities and challenges. This report provides an in-depth analysis of the current state and future implications of AI in finance, highlighting its applications, benefits, and risks.
#
# ## Background & Context
# The finance sector has historically been slow to adopt new technologies, but the advent of AI has changed this narrative. AI algorithms can process vast amounts of data, identify patterns, and make decisions faster and more accurately than humans. This has led to the development of various AI-powered financial tools and systems, such as chatbots, trading platforms, and risk management systems.
#
# ## Key Findings
# ...
